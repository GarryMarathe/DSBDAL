# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f1790773-70bc-48d7-9071-d62349354bd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1790773-70bc-48d7-9071-d62349354bd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips (1).csv

# %% [markdown]
# About this file
# Food servers’ tips in restaurants may be influenced by many
# factors, including the nature of the restaurant, size of the party, and table
# locations in the restaurant.
#  Restaurant managers need to know which factors
# matter when they assign tables to food servers. For the sake of staff morale,
# they usually want to avoid either the substance or the appearance of unfair
# treatment of the servers, for whom tips (at least in restaurants in the United
# States) are a major component of pay.
# In one restaurant, a food server recorded the following data on all
# cus-tomers they served during an interval of two and a half months in early 1990.
# The restaurant, located in a suburban shopping mall, was part of a national
# chain and served a varied menu. In observance of local law, the restaurant
# offered to seat in a non-smoking section to patrons who requested it. Each
# record includes a day and time, and taken together, they show the server’s
# work schedule.

# %%
import pandas as pd
import io
  
data = pd.read_csv(io.BytesIO(uploaded['tips.csv']),encoding='cp1252')
data.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **Let’s use the tips dataset in Seaborn next. The dataset consists of :**
#
# Information about the sex (gender)
# Time of day
# Total bill
# Tips given by customers visiting the restaurant for a week

# %% [markdown]
# **Barplot**

# %%
import seaborn as sns
sns.barplot(x='day',y='total_bill',data=data)

# %% [markdown]
# If you want to compare bar plots side-by-side, you can use the hue argument. The comparison will be done based on the third feature specified in this argument.

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=data)

# %%
sns.barplot(x = "day", y= "tip", hue = "smoker", palette = "pastel", data = data);

# %% [markdown]
# **Visualizing statistical relationships**

# %%
sns.set(style="darkgrid")
sns.relplot(x = "total_bill", y = "tip", data = data);

# %%
sns.relplot(x = "total_bill", y = "tip", hue= "smoker", data = data);

# %% [markdown]
# **Scatterplot**

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue= "sex", data = data);

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue= "smoker", style= "smoker", data = data);

# %%
sns.relplot(x = "total_bill",
            y = "tip",
            hue = "smoker",
            style = "time",
            height = 6,
            data = data);

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "size", height = 7, data = data);

# %% [markdown]
# **Plotting with categorical data**

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", data = data);

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "sex", data = data);

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "day", data = data);

# %% [markdown]
# **Lineplot**

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# draw lineplot
sns.lineplot(x="sex", y="total_bill", data=data)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')

plt.show()

# %%
sns.lineplot(x='day', y='tip', data=data)
plt.title('Title using Matplotlib Function')

plt.show()

# %% [markdown]
# **Countplot**

# %%
sns.countplot(x = "day", hue ="sex", data = data);

# %%
sns.countplot(x = "day", hue = "size", palette = "ch:.25", data = data)

# %%
f, ax = plt.subplots(figsize = (7,3))
sns.countplot(x = "day", hue= "smoker", data = data);

# %% [markdown]
# **Boxplot**

# %%
sns.boxplot(x = "day", y = "total_bill", data = data);

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "sex", data = data)

# %%
data["weekend"] = data["day"].isin(["Sat","Sun"])
data.sample(5)
# Out:
#      total_bill   tip   sex smoker   day    time  size  weekend
# 151       13.13  2.00  Male     No   Sun  Dinner     2     True
# 130       19.08  1.50  Male     No  Thur   Lunch     2    False
# 165       24.52  3.48  Male     No   Sun  Dinner     3     True
# 61        13.81  2.00  Male    Yes   Sat  Dinner     2     True
# 194       16.58  4.00  Male    Yes  Thur   Lunch     2    False

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "weekend", data = data);

# %% [markdown]
# **Violin Plot**
# Violin plots are used to visualize data distributions, displaying the range, median, and distribution of the data.
# Violin plots show the same summary statistics as box plots, but they also include Kernel Density Estimations that represent the shape/distribution of the data.
#  A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. It is used to visualize the distribution of numerical data. Unlike a box plot that can only show summary statistics, violin plots depict summary statistics and the density of each variable.
#  A violin plot is a method of plotting numeric data. ... While a box plot only shows summary statistics such as mean/median and interquartile ranges, the violin plot shows the full distribution of the data. The difference is particularly useful when the data distribution is multimodal (more than one peak).

# %%
sns.violinplot(x ="day", y = "total_bill", hue = "time", data = data);

# %%
sns.violinplot(x = "day", y = "total_bill", inner = None, data = data)

# %% [markdown]
# A swarmplot shows all the data points and that helps to understand the distribution in a better manner.

# %%
sns.swarmplot(x = "day", y = "total_bill", data = data);

# %%
sns.swarmplot(x = "day", y = "total_bill", hue = "sex", alpha = 0.90, data = data);

# %% [markdown]
# To control the transparency of plots, we can use the alpha argument within the plot function. By default, its value is 1. The value of this parameter ranges from 0 to 1, with the plot getting more transparent and invisible as the value reaches 0.

# %%
sns.swarmplot(x = "day", y = "total_bill", hue = "sex", alpha = .95, data = data);

# %%
sns.violinplot(x = "day", y = "total_bill", inner = None, data = data)
sns.swarmplot(x = "day", y = "total_bill", color = "k", size = 3, data = data);
